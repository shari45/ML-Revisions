# %% [markdown]
# # Q1. What's the version of NumPy that you installed?

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.20.1'

# %%
#data=wget 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'
# !wget $data

# %%
#Loading the Dataset
csv_data='data.csv'
df=pd.read_csv(csv_data)
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %% [markdown]
# # Q2. How many records are in the dataset?

# %%
len(df)
# Out:
# 11914

# %% [markdown]
# # Q3. Who are the most frequent car manufacturers (top-3) in the dataset?

# %%
df.Make.value_counts().head(3)
# Out:
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Name: Make, dtype: int64

# %% [markdown]
# # Q4. What's the number of unique Audi car models in the dataset?

# %%
fff=df.groupby('Make').Model.unique()
dd=fff.loc['Audi']
dd
# Out:
# array(['100', '200', '80', '90', 'A3', 'A4 allroad', 'A4', 'A5', 'A6',
#        'A7', 'A8', 'allroad quattro', 'allroad', 'Cabriolet', 'Coupe',
#        'Q3', 'Q5', 'Q7', 'R8', 'RS 4', 'RS 5', 'RS 6', 'RS 7', 'S3', 'S4',
#        'S5', 'S6', 'S7', 'S8', 'SQ5', 'TT RS', 'TT', 'TTS', 'V8'],
#       dtype=object)

# %%
count=0
for i in dd:
    count +=1
print(count)
# Out:
# 34

# %% [markdown]
# # Q5. How many columns in the dataset have missing values?

# %%
a=df.isnull().sum()
list(a)
# Out:
# [0, 0, 0, 3, 69, 30, 0, 0, 6, 3742, 0, 0, 0, 0, 0, 0]

# %%
columns=0
for i in a:
    if i>0:
        columns +=1
print(columns)
# Out:
# 5

# %% [markdown]
# # Q6.

# %% [markdown]
# 1. Find the median value of "Engine Cylinders" column in the dataset.

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %% [markdown]
# 2. Next, calculate the most frequent value of the same "Engine Cylinders".

# %%
df['Engine Cylinders'].value_counts().head(1)
# Out:
# 4.0    4752
# Name: Engine Cylinders, dtype: int64

# %% [markdown]
# OR

# %%
df['Engine Cylinders'].mode()
# Out:
# 0    4.0
# dtype: float64

# %% [markdown]
# 3. Use the fillna method to fill the missing values in "Engine Cylinders" with the most frequent value from the previous step.

# %%
df['Engine Cylinders']=df['Engine Cylinders'].fillna(4.0)
df['Engine Cylinders'].isnull().sum()
# Out:
# 0

# %% [markdown]
# 4. Now, calculate the median value of "Engine Cylinders" once again.

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %% [markdown]
# # Q7.

# %% [markdown]
# 1. Select all the "Lotus" cars from the dataset.

# %%
df[df=="Lotus"].count().head(5)
# Out:
# Make                29
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# dtype: int64

# %%
df[df['Make']=='Lotus']
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %% [markdown]
# 2. Select only columns "Engine HP", "Engine Cylinders".

# %%
df[['Engine HP', 'Engine Cylinders']].head(3)
# Out:
#    Engine HP  Engine Cylinders
# 0      335.0               6.0
# 1      300.0               6.0
# 2      300.0               6.0

# %% [markdown]
# 4. Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 9 rows).

# %%
dups=df.drop_duplicates()
dups.head(9)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
a=df.dtypes
index=[]
for i,b in enumerate(a):
    if b!='object':
        index +=[i]
ab=list(df.columns.values)
col_names=[]
for ia, ab in enumerate(ab):
    for i in index:
        if ia==i:
            col_names +=[ab]
col_names
# Out:
# ['Year',
#  'Engine HP',
#  'Engine Cylinders',
#  'Number of Doors',
#  'highway MPG',
#  'city mpg',
#  'Popularity',
#  'MSRP']

# %%
cols=df[col_names].head(15)
cols
# Out:
#     Year  Engine HP  Engine Cylinders  Number of Doors  highway MPG  city mpg  \
# 0   2011      335.0               6.0              2.0           26        19
# 1   2011      300.0               6.0              2.0           28        19
# 2   2011      300.0               6.0              2.0           28        20
# 3   2011      230.0               6.0              2.0           28        18
# 4   2011      230.0               6.0              2.0           28        18
# 5   2012      230.0               6.0              2.0           28        18
# 6   2012      300.0               6.0              2.0           26        17
# 7   2012      300.0               6.0              2.0           28        20
# 8   2012      230.0               6.0              2.0           28        18
# 9   2013      230.0               6.0              2.0           27        18
# 10  2013      300.0               6.0              2.0           28        20
# ...

# %% [markdown]
# 5. Get the underlying NumPy array. Let's call it X.

# %%
#X=np.array(two_cols)
X =np.array(cols)
X
# Out:
# array([[2.0110e+03, 3.3500e+02, 6.0000e+00, 2.0000e+00, 2.6000e+01,
#         1.9000e+01, 3.9160e+03, 4.6135e+04],
#        [2.0110e+03, 3.0000e+02, 6.0000e+00, 2.0000e+00, 2.8000e+01,
#         1.9000e+01, 3.9160e+03, 4.0650e+04],
#        [2.0110e+03, 3.0000e+02, 6.0000e+00, 2.0000e+00, 2.8000e+01,
#         2.0000e+01, 3.9160e+03, 3.6350e+04],
#        [2.0110e+03, 2.3000e+02, 6.0000e+00, 2.0000e+00, 2.8000e+01,
#         1.8000e+01, 3.9160e+03, 2.9450e+04],
#        [2.0110e+03, 2.3000e+02, 6.0000e+00, 2.0000e+00, 2.8000e+01,
#         1.8000e+01, 3.9160e+03, 3.4500e+04],
#        [2.0120e+03, 2.3000e+02, 6.0000e+00, 2.0000e+00, 2.8000e+01,
#         1.8000e+01, 3.9160e+03, 3.1200e+04],
#        [2.0120e+03, 3.0000e+02, 6.0000e+00, 2.0000e+00, 2.6000e+01,
#         1.7000e+01, 3.9160e+03, 4.4100e+04],
#        [2.0120e+03, 3.0000e+02, 6.0000e+00, 2.0000e+00, 2.8000e+01,
#         2.0000e+01, 3.9160e+03, 3.9300e+04],
# ...

# %% [markdown]
# 6. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# Invert XTX.

# %%
X_t=X.transpose()
XTX=X.dot(X_t)
XTX
# Out:
# array([[2.14793070e+09, 1.89486856e+09, 1.69648808e+09, 1.37813309e+09,
#         1.61111484e+09, 1.45887135e+09, 2.05403623e+09, 1.83258834e+09,
#         1.72184085e+09, 1.73568333e+09, 1.84643085e+09, 1.47271388e+09,
#         2.06787883e+09, 1.73568338e+09, 1.47271388e+09],
#        [1.89486856e+09, 1.67189286e+09, 1.49709788e+09, 1.21659184e+09,
#         1.42187434e+09, 1.28773135e+09, 1.81213728e+09, 1.61701739e+09,
#         1.51943635e+09, 1.53163334e+09, 1.62921440e+09, 1.29992838e+09,
#         1.82433438e+09, 1.53163338e+09, 1.29992838e+09],
#        [1.69648808e+09, 1.49709788e+09, 1.34079290e+09, 1.08995686e+09,
#         1.27352436e+09, 1.15357137e+09, 1.62250730e+09, 1.44802741e+09,
#         1.36076637e+09, 1.37167336e+09, 1.45893442e+09, 1.16447840e+09,
#         1.63341440e+09, 1.37167340e+09, 1.16447840e+09],
#        [1.37813309e+09, 1.21659184e+09, 1.08995686e+09, 8.86735725e+08,
#         1.03545822e+09, 9.38275236e+08, 1.31819626e+09, 1.17683637e+09,
# ...

# %%
inv_XTX=np.linalg.pinv(XTX).round(2)

# %%
inv_XTX
# Out:
# array([[ 0.21, -0.08,  0.07, -0.03,  0.02, -0.09, -0.09,  0.02, -0.03,
#          0.1 , -0.05,  0.03, -0.19,  0.09,  0.03],
#        [-0.08,  0.06, -0.01,  0.02,  0.03,  0.03,  0.  , -0.  ,  0.04,
#         -0.06, -0.  , -0.04,  0.07, -0.03, -0.04],
#        [ 0.07, -0.01,  0.03, -0.01,  0.02, -0.04, -0.05,  0.01,  0.  ,
#          0.02, -0.02, -0.  , -0.06,  0.04, -0.  ],
#        [-0.03,  0.02, -0.01,  0.02,  0.01,  0.02,  0.03, -0.01,  0.01,
#         -0.02, -0.  , -0.01,  0.03, -0.03, -0.01],
#        [ 0.02,  0.03,  0.02,  0.01,  0.05, -0.02, -0.04,  0.01,  0.03,
#         -0.01, -0.03, -0.03, -0.02,  0.01, -0.03],
#        [-0.09,  0.03, -0.04,  0.02, -0.02,  0.05,  0.07, -0.02,  0.01,
#         -0.04,  0.02, -0.01,  0.08, -0.05, -0.01],
#        [-0.09,  0.  , -0.05,  0.03, -0.04,  0.07,  0.11, -0.03, -0.01,
#         -0.02,  0.02,  0.01,  0.07, -0.07,  0.01],
#        [ 0.02, -0.  ,  0.01, -0.01,  0.01, -0.02, -0.03,  0.01,  0.  ,
# ...

# %% [markdown]
# 7. Create an array y with values [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800].

# %%
y=np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300])
y
# Out:
# array([1100,  800,  750,  850, 1300, 1000, 1000, 1300])

# %% [markdown]
# 8. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.

# %%
XTX_X=X_t.dot(XTX)
XTX_X
# Out:
# array([[5.25690786e+13, 4.63887185e+13, 4.15438053e+13, 3.37688477e+13,
#         3.94588046e+13, 3.57406757e+13, 5.02759747e+13, 4.48677022e+13,
#         4.21630033e+13, 4.25010804e+13, 4.52057801e+13, 3.60787542e+13,
#         5.06140554e+13, 4.25010818e+13, 3.60787542e+13],
#        [7.03219760e+12, 6.20530342e+12, 5.55708398e+12, 4.51684235e+12,
#         5.27812341e+12, 4.78066062e+12, 6.72539415e+12, 6.00180072e+12,
#         5.63992835e+12, 5.68516085e+12, 6.04703333e+12, 4.82589331e+12,
#         6.77062714e+12, 5.68516104e+12, 4.82589331e+12],
#        [1.56761857e+11, 1.38331921e+11, 1.23884310e+11, 1.00699258e+11,
#         1.17666803e+11, 1.06579281e+11, 1.49923783e+11, 1.33796225e+11,
#         1.25730768e+11, 1.26738920e+11, 1.34804379e+11, 1.07587437e+11,
#         1.50931946e+11, 1.26738924e+11, 1.07587437e+11],
#        [5.22539523e+10, 4.61106403e+10, 4.12947698e+10, 3.35664192e+10,
#         3.92222677e+10, 3.55264271e+10, 4.99745944e+10, 4.45987417e+10,
# ...

# %%
w=y.dot(XTX_X)

# %% [markdown]
# 9. What's the value of the first element of w?

# %%
w[0]
# Out:
# 1.4575561506877486e+18
